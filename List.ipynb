# %% [markdown]
# # **List**
# - A list in Python is an ordered, mutable collection that can store items of any data type.
#  - list vs array
#  - create
#  - access
#  - edit
#  - add
#  - delete
#  - operations
#  - functions

# %% [markdown]
# - Arrays are homogenous List is heterogenous.
# - Arrays are much faster.
# - Lists are more programmer friendly.

# %%
l =[]
l
# Out:
# []

# %%
l = [1,2,3,4,5]
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %%
#Mulitdimensional list
#2D
l = [1,2,3,[4,5]]
print(l) 
print(l[3][0])
# Out:
# [1, 2, 3, [4, 5]]
# 4

# %%
#3D list
l = [[[1,2],[3,4]],[[5,6],[7,8]]]
print(l)
print(l[1][1][0])
# Out:
# [[[1, 2], [3, 4]], [[5, 6], [7, 8]]]
# 7

# %%
l = list("sandeep")
print(l)
# Out:
# ['s', 'a', 'n', 'd', 'e', 'e', 'p']

# %%
#list in python are mutable
l = [1,2,3,4,5]
l[-1]=8
print(l)
# Out:
# [1, 2, 3, 4, 8]

# %%
l.append("sandeep")
print(l)
# Out:
# [1, 2, 3, 4, 8, 'sandeep']

# %%
l.extend([5000,0000])
print(l)
# Out:
# [1, 2, 3, 4, 8, 'sandeep', 5000, 0]

# %%
l.append([1,12])
print(l)
# Out:
# [1, 2, 3, 4, 8, 'sandeep', 5000, 0, [1, 12]]

# %%
l.extend("sand")
print(l)
# Out:
# [1, 2, 3, 4, 8, 'sandeep', 5000, 0, [1, 12], 's', 'a', 'n', 'd']

# %%
l.insert(1,"world")
print(l)
# Out:
# [1, 'world', 2, 3, 4, 8, 'sandeep', 5000, 0, [1, 12], 's', 'a', 'n', 'd']

# %%
# del keyword is used to deleted entire list
l.remove("sandeep")
print(l)
# Out:
# [1, 'world', 2, 3, 4, 8, 5000, 0, [1, 12], 's', 'a', 'n', 'd']

# %%
#You can perform different operations on list which are available like 
# multiply , add , concat and division etc
