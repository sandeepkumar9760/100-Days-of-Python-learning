# %% [markdown]
# # Modules
#
# - Consider a module to be same as a code library
#
# * A file containing a set of functions you want to include in your application.
#  ## Some of the famous modules are as follows:-
#  * maths
#  * os
#  * random
#  * time
