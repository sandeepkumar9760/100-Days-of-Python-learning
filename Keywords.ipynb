# %% [markdown]
# # Keywords
# - Python is case sensitive programming language.
# * Keywords are reserved words in Python that have predefined meanings and special purposes. They cannot be used as variable names, function names, or identifiers.

# %%
#python has 33 keywords 
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # Identifiers
#
# *Rules for setting identifiers*
# - can only start with an alphabet or _.
# - Followed by 0 or more than _ and digits
# - keywords cannot be used as identifiers

# %%
name1 = "sandeep"
print(name1)
# Out:
# sandeep

# %%
1name = "sandeep"
#this will throw an error
print(1name)
# Out:
#   Cell In[3], line 1
#     1name = "sandeep"
#     ^
# SyntaxError: invalid decimal literal

# %%
_name = "sandeep"
print(_name)
# Out:
# sandeep

# %%
True = "sandeep"
print(True)
#this will throe an error as True is a keyword in python
# Out:
#   Cell In[5], line 1
#     True = "sandeep"
#     ^
# SyntaxError: cannot assign to True
