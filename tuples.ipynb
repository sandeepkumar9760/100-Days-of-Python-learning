# %% [markdown]
# # **Tuples**
# - A tuple in Python is an ordered, immutable collection of items. Once a tuple is created, its elements cannot be changed, added, or removed.
# - Create
# - Access
# - Edit
# - Add
# - Delete
# - Operations
# - Functions

# %%
t =()
print(type(t))
# Out:
# <class 'tuple'>

# %%
#Creation of tuple and list is same 
# the only difference is of brackets ().

# %%
#Accessing is same as list

# %%
#Tuple is not mutable
#Tuple is immutable just like strings in python.
#You can just delete the whole tuple (del) but not any index as tuple is immutable

# %%
#Operations are same as in the list in tuple.

# %%
#Tuples are read-only data type in python
