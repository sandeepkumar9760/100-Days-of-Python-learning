# %% [markdown]
# ## **Operations on Strings**
#
# * Arithmetic Operations
# * Relational Operations
# * Logical Operations
# * Loops on Strings
# * Membership Operations

# %%
a = "Hello" + "World"
print(a)
# Out:
# HelloWorld

# %%
print("*"*10)
# Out:
# **********

# %%
print("hello"*5)
# Out:
# hellohellohellohellohello

# %%
a = "hello"
b = "you are buffalo"
c = "hello"
print(a==b)
print(a==c)
# Out:
# False
# True

# %%
print(a<b)

#According to dictionary counting
# Out:
# True

# %%
print("hello" and "world")
# Out:
# world

# %% [markdown]
# - world is printing because in python empty string is classified as false and non empty true so, (**1 and 1**) gives last 1.

# %%
print("world" and "hello")
# Out:
# hello

# %%
print("world" or "hello")
# Out:
# world

# %%
print("world" or "")
# Out:
# world

# %%
print("" or "hello")
# Out:
# hello

# %% [markdown]
# - **or** operator check if any of the string is true or not so whichever string appears to be non empty first it prints that.

# %%
c = "sandeep kumar"

for i in c :
    print(i,end="")
# Out:
# sandeep kumar

# %%
for i in c[::-1]:
    print(i,end="")
# Out:
# ramuk peednas

# %%
a = "sandeep"

print("a" in a)
# Out:
# True

# %%
print("t" in a)
# Out:
# False
