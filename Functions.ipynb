# %%
print("Hellow world")
# Out:
# Hellow world

# %%
print(5.6)
print(6)
print("INDIA","USA","London")
print("INDIA","USA","London",sep="-")
print("Snadeep")
print("Kumar")
print("Sandeep", end='')
print("Kumar")
# Out:
# 5.6
# 6
# INDIA USA London
# INDIA-USA-London
# Snadeep
# Kumar
# SandeepKumar

# %%
print(False)
print(True)

#Basically you can print anything
# Out:
# False
# True
