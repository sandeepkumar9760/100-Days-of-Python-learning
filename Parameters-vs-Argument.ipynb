# %% [markdown]
# # **Parameters vs Arguments in Python**
#
# - Although the terms are often used interchangeably, they have different meanings.
#
# ## Parameter ##
# - A variable defined in the function definition.
# - Placeholder for data.
# - Exists inside the function declaration.
# ## Argument ##
# - The actual value passed to the function when it is called.
# - Real data supplied to the function.
# - Exists in the function call.

# %%
#Example
def greet(name):      # 'name' is a parameter
    print("Hello,", name)

greet("Alice")        # "Alice" is an argument
# Out:
# Hello, Alice

# %%
#Another example
def add(a, b):        # a and b are parameters
    return a + b

result = add(10, 20)  # 10 and 20 are arguments
print(result)
# Out:
# 30

# %% [markdown]
# ## Types of Arguments ##
# 1. Positional Arguments
#
# Arguments are matched with parameters based on their position.

# %%
def student(name, age):
    print(name, age)

student("John", 20)
# Out:
# John 20

# %% [markdown]
# 2. Keyword Arguments
#
# Arguments are passed using the parameter names.

# %%
def student(name, age):
    print(name, age)

student(age=20, name="John")
# Out:
# John 20

# %% [markdown]
# 3. Default Arguments
#
# A parameter has a default value that is used if no argument is provided.

# %%
def greet(name="Guest"):
    print("Hello,", name)

greet()
greet("Alice")
# Out:
# Hello, Guest
# Hello, Alice

# %% [markdown]
# 4. Variable-Length Arguments
#  - *args (Multiple Positional Arguments)

# %%
def add(*numbers):
    print(sum(numbers))

add(1, 2, 3, 4)
# Out:
# 10

# %% [markdown]
# * **kwargs (Multiple Keyword Arguments) *

# %%
def student(**details):
    print(details)

student(name="John", age=20)
# Out:
# {'name': 'John', 'age': 20}
